# %% [markdown]
# ![reddit%20submission.PNG](attachment:reddit%20submission.PNG)

# %% [markdown]
# Jan 27 = GME closes at 347.51 dollars
# Jan 28 = Robinhood restricts GME trading.(restricted buying but selling allowed)
# Very large number of submissions in early February then shows a constant decline.
# Feb 1 = Robinhood raises 2.4 billion in capital after raising 1 billion the previous week
# Feb 2 = GME opens at 50% down at 140.76 dollars (Lots of people lost money -----> possibly more submissions)
# Feb 4 = US treasury secretary Janet Yellen calls meeting to discuss market volatility driven stocks such as GME.
#
# **Still in the process of getting more data from 1/1/2021 to 1/31/2021**
#
# Once all the data is gathered, filter through the text for stock mentions, then aggregated the times each stock is mentioned throughout the period 1/1~4/26. Possibly be able to see a trend.
